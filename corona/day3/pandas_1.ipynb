# %%
import pandas as pd

# %%
pd.read_csv('food.csv')
# Out:
#    Unnamed: 0   Product                Brand  Cost
# 0           1   Biryani             Paradise   180
# 1           2     Pizza              Dominos   150
# 2           3     Tacos             TacoBell   280
# 3           4  Burritos  California Burritos   250
# 4           5    Coffee           Star Bucks   110

# %%
food = pd.read_csv('food.csv')

# %%
food.shape
# Out:
# (5, 4)

# %%
cricket = pd.read_csv("matches.csv")

# %%
cricket.shape
# Out:
# (636, 18)

# %%
cricket
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
cricket[0:20]
# Out:
#     id  season       city        date                        team1  \
# 0    1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1    2    2017       Pune  2017-04-06               Mumbai Indians
# 2    3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3    4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4    5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5    6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6    7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 7    8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 8    9    2017       Pune  2017-04-11             Delhi Daredevils
# 9   10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
# 10  11    2017    Kolkata  2017-04-13              Kings XI Punjab
# 11  12    2017  Bangalore  2017-04-14  Royal Challengers Bangalore
# 12  13    2017     Rajkot  2017-04-14       Rising Pune Supergiant
# ...

# %%
cricket.head(7)
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# ...

# %%
cricket.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
listc = list(food.columns)

# %%
listc
# Out:
# ['Unnamed: 0', 'Product', 'Brand', 'Cost']

# %%
food
# Out:
#    Unnamed: 0   Product                Brand  Cost
# 0           1   Biryani             Paradise   180
# 1           2     Pizza              Dominos   150
# 2           3     Tacos             TacoBell   280
# 3           4  Burritos  California Burritos   250
# 4           5    Coffee           Star Bucks   110

# %%
print(type(food))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
food.shape
# Out:
# (5, 4)

# %%
cricket
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
cricket.season
# Out:
# 0      2017
# 1      2017
# 2      2017
# 3      2017
# 4      2017
#        ...
# 631    2016
# 632    2016
# 633    2016
# 634    2016
# 635    2016
# Name: season, Length: 636, dtype: int64

# %%
cricket.season.unique()
# Out:
# array([2017, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016])

# %%
print(cricket)
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
ipl_season = list(cricket.season.unique())

# %%
ipl_season
# Out:
# [2017, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016]

# %%
food
# Out:
#    Unnamed: 0   Product                Brand  Cost
# 0           1   Biryani             Paradise   180
# 1           2     Pizza              Dominos   150
# 2           3     Tacos             TacoBell   280
# 3           4  Burritos  California Burritos   250
# 4           5    Coffee           Star Bucks   110

# %%
listb = ['dosa', 'halua', 'idli', 'aloo paratha', 'chapathi']
listc = ['a2b', 'maa ke haath', 'adigas', 'parathawaala', 'boxwaala']
Cost = [80, 11, 55, 60, 30]

# %%
dicta = {'Dish':listb, 'Brand':listc, 'Cost':Cost}

# %%
meal = pd.DataFrame(dicta)

# %%
meal
# Out:
#            Dish         Brand  Cost
# 0          dosa           a2b    80
# 1         halua  maa ke haath    11
# 2          idli        adigas    55
# 3  aloo paratha  parathawaala    60
# 4      chapathi      boxwaala    30

# %%
meal.index= ['first', 'second', 'third', 'fourth', 'fifth']

# %%
meal
# Out:
#                 Dish         Brand  Cost
# first           dosa           a2b    80
# second         halua  maa ke haath    11
# third           idli        adigas    55
# fourth  aloo paratha  parathawaala    60
# fifth       chapathi      boxwaala    30

# %%
meal['Brand']
# Out:
# first              a2b
# second    maa ke haath
# third           adigas
# fourth    parathawaala
# fifth         boxwaala
# Name: Brand, dtype: object

# %%
meal.Brand
# Out:
# first              a2b
# second    maa ke haath
# third           adigas
# fourth    parathawaala
# fifth         boxwaala
# Name: Brand, dtype: object

# %%
cricket['season'].unique()
# Out:
# array([2017, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016])

# %%
food[ ['Brand', 'Product'] ]
# Out:
#                  Brand   Product
# 0             Paradise   Biryani
# 1              Dominos     Pizza
# 2             TacoBell     Tacos
# 3  California Burritos  Burritos
# 4           Star Bucks    Coffee

# %%
#    food.loc (any type index)
#    food.iloc (numeric index)

# %%
meal.loc[['second', 'third']]
# Out:
#          Dish         Brand  Cost
# second  halua  maa ke haath    11
# third    idli        adigas    55

# %%
food
# Out:
#    Unnamed: 0   Product                Brand  Cost
# 0           1   Biryani             Paradise   180
# 1           2     Pizza              Dominos   150
# 2           3     Tacos             TacoBell   280
# 3           4  Burritos  California Burritos   250
# 4           5    Coffee           Star Bucks   110

# %%
food.rename(columns= {'Unnamed: 0':'num'} )
# Out:
#    num   Product                Brand  Cost
# 0    1   Biryani             Paradise   180
# 1    2     Pizza              Dominos   150
# 2    3     Tacos             TacoBell   280
# 3    4  Burritos  California Burritos   250
# 4    5    Coffee           Star Bucks   110

# %%
food
# Out:
#    Unnamed: 0   Product                Brand  Cost
# 0           1   Biryani             Paradise   180
# 1           2     Pizza              Dominos   150
# 2           3     Tacos             TacoBell   280
# 3           4  Burritos  California Burritos   250
# 4           5    Coffee           Star Bucks   110

# %%
food.rename(columns= {'Unnamed: 0':'num'} , inplace=True)

# %%
food
# Out:
#    num   Product                Brand  Cost
# 0    1   Biryani             Paradise   180
# 1    2     Pizza              Dominos   150
# 2    3     Tacos             TacoBell   280
# 3    4  Burritos  California Burritos   250
# 4    5    Coffee           Star Bucks   110

# %%
food['Price'] = food.eval('Cost*(1.05)')

# %%
food
# Out:
#    num   Product                Brand  Cost  Price
# 0    1   Biryani             Paradise   180  189.0
# 1    2     Pizza              Dominos   150  157.5
# 2    3     Tacos             TacoBell   280  294.0
# 3    4  Burritos  California Burritos   250  262.5
# 4    5    Coffee           Star Bucks   110  115.5

# %%
food.describe()
# Out:
#             num        Cost       Price
# count  5.000000    5.000000    5.000000
# mean   3.000000  194.000000  203.700000
# std    1.581139   70.213959   73.724657
# min    1.000000  110.000000  115.500000
# 25%    2.000000  150.000000  157.500000
# 50%    3.000000  180.000000  189.000000
# 75%    4.000000  250.000000  262.500000
# max    5.000000  280.000000  294.000000

# %%
food.Price.max()
# Out:
# 294.0

# %%
print(type(food.Price.max))
# Out:
# <class 'method'>

# %%
x = food.Price.max

# %%
print(type(x))
# Out:
# <class 'method'>

# %%
x
# Out:
# <bound method Series.max of 0    189.0
# 1    157.5
# 2    294.0
# 3    262.5
# 4    115.5
# Name: Price, dtype: float64>

# %%
football = pd.read_csv('results.csv')

# %%
football.head(10)
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
# 5  1876-03-25  Scotland     Wales           4           0   Friendly  Glasgow
# 6  1877-03-03   England  Scotland           1           3   Friendly   London
# 7  1877-03-05     Wales  Scotland           0           2   Friendly  Wrexham
# 8  1878-03-02  Scotland   England           7           2   Friendly  Glasgow
# 9  1878-03-23  Scotland     Wales           9           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# ...

# %%
football.shape
# Out:
# (41586, 9)

# %%
football.tournament.unique()
# Out:
# array(['Friendly', 'British Championship', 'Copa Lipton', 'Copa Newton',
#        'Copa Premio Honor Argentino', 'Copa Premio Honor Uruguayo',
#        'Copa Roca', 'Copa América', 'Copa Chevallier Boutell',
#        'Nordic Championship', 'International Cup', 'Baltic Cup',
#        'Balkan Cup', 'FIFA World Cup', 'Copa Rio Branco',
#        'FIFA World Cup qualification', 'CCCF Championship',
#        'NAFU Championship', 'Copa Oswaldo Cruz',
#        'Pan American Championship', 'Copa del Pacífico',
#        "Copa Bernardo O'Higgins", 'AFC Asian Cup qualification',
#        'Atlantic Cup', 'AFC Asian Cup', 'African Cup of Nations',
#        'Copa Paz del Chaco', 'Merdeka Tournament',
#        'UEFA Euro qualification', 'UEFA Euro',
#        'Windward Islands Tournament',
#        'African Cup of Nations qualification', 'Vietnam Independence Cup',
#        'Copa Carlos Dittborn', 'CONCACAF Championship',
#        'Copa Juan Pinto Durán', 'UAFA Cup', 'South Pacific Games',
# ...

# %%
tour = list(football.tournament.unique())

# %%
len(tour)
# Out:
# 112

# %%
football.columns
# Out:
# Index(['date', 'home_team', 'away_team', 'home_score', 'away_score',
#        'tournament', 'city', 'country', 'neutral'],
#       dtype='object')

# %%
#    football['tournament'] == 'FIFA World Cup'

fifa = football[football['tournament'] == 'FIFA World Cup']

# %%
fifa
# Out:
#              date  home_team      away_team  home_score  away_score  \
# 1304   1930-07-13    Belgium  United States           0           3
# 1305   1930-07-13     France         Mexico           4           1
# 1306   1930-07-14     Brazil     Yugoslavia           1           2
# 1307   1930-07-14       Peru        Romania           1           3
# 1308   1930-07-15  Argentina         France           1           0
# ...           ...        ...            ...         ...         ...
# 39945  2018-07-07     Russia        Croatia           2           2
# 39946  2018-07-10     France        Belgium           1           0
# 39947  2018-07-11    Croatia        England           2           1
# 39948  2018-07-14    Belgium        England           2           0
# 39949  2018-07-15     France        Croatia           4           2
#
#            tournament            city  country  neutral
# 1304   FIFA World Cup      Montevideo  Uruguay     True
# ...

# %%
fifa.country.unique()
# Out:
# array(['Uruguay', 'Italy', 'France', 'Brazil', 'Switzerland', 'Sweden',
#        'Chile', 'England', 'Mexico', 'Germany', 'Argentina', 'Spain',
#        'United States', 'South Korea', 'Japan', 'South Africa', 'Russia'],
#       dtype=object)
