# %%
import pandas as pd

# %%
dfa = pd.read_csv("annual-balance-sheets-and-accumulation-accounts-200817-provisional-csv.csv")

# %%
dfa.shape
# Out:
# (18720, 8)

# %%
dfa
# Out:
#           Year       Institutional_sector_name  Institutional_sector_code  \
# 0      2008.03  Corporate business enterprises                        141
# 1      2009.03  Corporate business enterprises                        141
# 2      2010.03  Corporate business enterprises                        141
# 3      2011.03  Corporate business enterprises                        141
# 4      2012.03  Corporate business enterprises                        141
# ...        ...                             ...                        ...
# 18715  2013.03                   Pension funds                        261
# 18716  2014.03                   Pension funds                        261
# 18717  2015.03                   Pension funds                        261
# 18718  2016.03                   Pension funds                        261
# 18719  2017.03                   Pension funds                        261
#
#                                               Descriptor SNA08TRANS  \
# ...

# %%
dfa.columns
# Out:
# Index(['Year', 'Institutional_sector_name', 'Institutional_sector_code',
#        'Descriptor', 'SNA08TRANS', 'Asset_liability_code', 'Status', 'Values'],
#       dtype='object')

# %%
list(dfa.columns)
# Out:
# ['Year',
#  'Institutional_sector_name',
#  'Institutional_sector_code',
#  'Descriptor',
#  'SNA08TRANS',
#  'Asset_liability_code',
#  'Status',
#  'Values']

# %%
dfa.dtypes
# Out:
# Year                         float64
# Institutional_sector_name     object
# Institutional_sector_code      int64
# Descriptor                    object
# SNA08TRANS                    object
# Asset_liability_code          object
# Status                        object
# Values                        object
# dtype: object

# %%
dfa['Institutional_sector_code']
# Out:
# 0        141
# 1        141
# 2        141
# 3        141
# 4        141
#         ...
# 18715    261
# 18716    261
# 18717    261
# 18718    261
# 18719    261
# Name: Institutional_sector_code, Length: 18720, dtype: int64

# %%
dfa['Institutional_sector_code'].mean()
# Out:
# 260.72222222222223

# %%
dfa.describe()
# Out:
#                Year  Institutional_sector_code
# count  18720.000000               18720.000000
# mean    2012.530000                 260.722222
# std        2.872358                 144.607845
# min     2008.030000                   8.000000
# 25%     2010.030000                 211.000000
# 50%     2012.530000                 246.000000
# 75%     2015.030000                 312.000000
# max     2017.030000                 611.000000

# %%
dfa['Institutional_sector_name'].nunique()
# Out:
# 18

# %%
dfa['SNA08TRANS'].nunique()
# Out:
# 24

# %%
dfa['Institutional_sector_name'].unique()
# Out:
# array(['Corporate business enterprises', 'Financial auxiliaries',
#        'Captive financial institutions',
#        'Central government institutions excluding funded social insurance schemes',
#        'Central government institutions funded social insurance schemes',
#        'Local government institutions',
#        'Non-profit institutions serving households', 'Households',
#        'Total economy (excl rest of the world)', 'Rest of the world',
#        'Non-corporate business enterprises', 'Central bank',
#        'Registered banks', 'Other depository institutions',
#        'Investment funds',
#        'Other financial intermediaries excluding insurance and pension funds',
#        'Insurance corporations', 'Pension funds'], dtype=object)

# %%
dfa['Institutional_sector_name'].value_counts()
# Out:
# Central government institutions funded social insurance schemes              1040
# Local government institutions                                                1040
# Other financial intermediaries excluding insurance and pension funds         1040
# Non-corporate business enterprises                                           1040
# Investment funds                                                             1040
# Insurance corporations                                                       1040
# Corporate business enterprises                                               1040
# Captive financial institutions                                               1040
# Registered banks                                                             1040
# Other depository institutions                                                1040
# Financial auxiliaries                                                        1040
# ...

# %%
dfa['SNA08TRANS'].value_counts()
# Out:
# K070000    3780
# LE00000    3780
# LS00000    3780
# F000000    3240
# K050000     720
# D990000     180
# B09C000     180
# K060000     180
# NP00000     180
# NP02000     180
# B08N000     180
# B102000     180
# P051C00     180
# K061000     180
# D910000     180
# K030000     180
# NP01000     180
# P052000     180
# K062000     180
# B103000     180
# P051000     180
# P051G00     180
# B09F000     180
# B090000     180
# Name: SNA08TRANS, dtype: int64

# %%
dfa
# Out:
#           Year       Institutional_sector_name  Institutional_sector_code  \
# 0      2008.03  Corporate business enterprises                        141
# 1      2009.03  Corporate business enterprises                        141
# 2      2010.03  Corporate business enterprises                        141
# 3      2011.03  Corporate business enterprises                        141
# 4      2012.03  Corporate business enterprises                        141
# ...        ...                             ...                        ...
# 18715  2013.03                   Pension funds                        261
# 18716  2014.03                   Pension funds                        261
# 18717  2015.03                   Pension funds                        261
# 18718  2016.03                   Pension funds                        261
# 18719  2017.03                   Pension funds                        261
#
#                                               Descriptor SNA08TRANS  \
# ...

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/shobhit/Desktop/infineon/day4/pandas'

# %%
path = '/Users/shobhit/Desktop/infineon/day2/files/data.txt'

# %%
dfb = pd.read_csv(path, delimiter=' ')

# %%
dfb
# Out:
#    22  ggg  44  tre
# 0  77  hyg  12  vft
# 1  89  gse  66  qwe
# 2  99  vft  10  zse
# 3  89  lio  16  vft

# %%
dfb = pd.read_csv(path, delimiter=' ', header=None)

# %%
dfb
# Out:
#     0    1   2    3
# 0  22  ggg  44  tre
# 1  77  hyg  12  vft
# 2  89  gse  66  qwe
# 3  99  vft  10  zse
# 4  89  lio  16  vft

# %%
dfb.columns = ['ttt', 'yyy', 'zzz', 'iii']

# %%
dfb
# Out:
#    ttt  yyy  zzz  iii
# 0   22  ggg   44  tre
# 1   77  hyg   12  vft
# 2   89  gse   66  qwe
# 3   99  vft   10  zse
# 4   89  lio   16  vft

# %%
dfb[['ttt', 'yyy']]
# Out:
#    ttt  yyy
# 0   22  ggg
# 1   77  hyg
# 2   89  gse
# 3   99  vft
# 4   89  lio

# %%
dfb.iloc[1:3]
# Out:
#    ttt  yyy  zzz  iii
# 1   77  hyg   12  vft
# 2   89  gse   66  qwe

# %%
dfb.loc[1:3, ['ttt', 'yyy']]
# Out:
#    ttt  yyy
# 1   77  hyg
# 2   89  gse
# 3   99  vft

# %%
dfb.loc[1:3, ['ttt', 'yyy']]
# Out:
#    ttt  yyy
# 1   77  hyg
# 2   89  gse
# 3   99  vft

# %%
dfa.loc[20:33, ['SNA08TRANS', 'Asset_liability_code']]
# Out:
#    SNA08TRANS Asset_liability_code
# 20    LS00000              AN00000
# 21    LS00000              AN00000
# 22    LS00000              AN00000
# 23    LS00000              AN00000
# 24    LS00000              AN00000
# 25    LS00000              AN00000
# 26    LS00000              AN00000
# 27    LS00000              AN00000
# 28    LS00000              AN00000
# 29    LS00000              AN00000
# 30    P051G00              AN10000
# 31    P051G00              AN10000
# 32    P051G00              AN10000
# 33    P051G00              AN10000

# %%
dfa['Institutional_sector_name'] == 'Pension funds'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18715     True
# 18716     True
# 18717     True
# 18718     True
# 18719     True
# Name: Institutional_sector_name, Length: 18720, dtype: bool

# %%
dfa[ dfa['Institutional_sector_name'] == 'Pension funds']
# Out:
#           Year Institutional_sector_name  Institutional_sector_code  \
# 17680  2008.03             Pension funds                        261
# 17681  2009.03             Pension funds                        261
# 17682  2010.03             Pension funds                        261
# 17683  2011.03             Pension funds                        261
# 17684  2012.03             Pension funds                        261
# ...        ...                       ...                        ...
# 18715  2013.03             Pension funds                        261
# 18716  2014.03             Pension funds                        261
# 18717  2015.03             Pension funds                        261
# 18718  2016.03             Pension funds                        261
# 18719  2017.03             Pension funds                        261
#
#                                               Descriptor SNA08TRANS  \
# 17680  Capital Account Opening balances Produced non-...    LS00000
# ...

# %%
dfa[ (dfa['Institutional_sector_name'] == 'Pension funds') & (dfa['SNA08TRANS'] == 'LS00000')]
# Out:
#           Year Institutional_sector_name  Institutional_sector_code  \
# 17680  2008.03             Pension funds                        261
# 17681  2009.03             Pension funds                        261
# 17682  2010.03             Pension funds                        261
# 17683  2011.03             Pension funds                        261
# 17684  2012.03             Pension funds                        261
# ...        ...                       ...                        ...
# 18025  2013.03             Pension funds                        261
# 18026  2014.03             Pension funds                        261
# 18027  2015.03             Pension funds                        261
# 18028  2016.03             Pension funds                        261
# 18029  2017.03             Pension funds                        261
#
#                                               Descriptor SNA08TRANS  \
# 17680  Capital Account Opening balances Produced non-...    LS00000
# ...

# %%
dfa_tt = dfa[ (dfa['Institutional_sector_name'] == 'Pension funds') & (dfa['SNA08TRANS'] == 'LS00000')]

# %%
dfa_tt.shape
# Out:
# (210, 8)

# %%
dfa_tt['Institutional_sector_code'].mean()
# Out:
# 261.0

# %%
dfa_tt['Institutional_sector_code'].std()
# Out:
# 0.0

# %%
dfb
# Out:
#    ttt  yyy  zzz  iii
# 0   22  ggg   44  tre
# 1   77  hyg   12  vft
# 2   89  gse   66  qwe
# 3   99  vft   10  zse
# 4   89  lio   16  vft

# %%
dfb.dtypes
# Out:
# ttt     int64
# yyy    object
# zzz     int64
# iii    object
# dtype: object

# %%
dfb [ (dfb['ttt'] > 80) & (dfb['zzz'] <50) ]
# Out:
#    ttt  yyy  zzz  iii
# 3   99  vft   10  zse
# 4   89  lio   16  vft

# %%
dfb [ (dfb['ttt'] > 80) & (dfb['zzz'] <50) ]['zzz'].mean()
# Out:
# 13.0

# %%
dfa
# Out:
#           Year       Institutional_sector_name  Institutional_sector_code  \
# 0      2008.03  Corporate business enterprises                        141
# 1      2009.03  Corporate business enterprises                        141
# 2      2010.03  Corporate business enterprises                        141
# 3      2011.03  Corporate business enterprises                        141
# 4      2012.03  Corporate business enterprises                        141
# ...        ...                             ...                        ...
# 18715  2013.03                   Pension funds                        261
# 18716  2014.03                   Pension funds                        261
# 18717  2015.03                   Pension funds                        261
# 18718  2016.03                   Pension funds                        261
# 18719  2017.03                   Pension funds                        261
#
#                                               Descriptor SNA08TRANS  \
# ...

# %%
dfc = dfa.copy()

# %%
dfc['Year format'] = dfa['Year']*100     
dfc['Year format'] = pd.to_datetime(dfc['Year format'], format='%Y%m')

# %%
dfc.dtypes
# Out:
# Year                         float64
# Institutional_sector_name     object
# Institutional_sector_code      int64
# Descriptor                    object
# SNA08TRANS                    object
# Asset_liability_code          object
# Status                        object
# Values                        object
# dtype: object

# %%
dfc
# Out:
#           Year       Institutional_sector_name  Institutional_sector_code  \
# 0      2008.03  Corporate business enterprises                        141
# 1      2009.03  Corporate business enterprises                        141
# 2      2010.03  Corporate business enterprises                        141
# 3      2011.03  Corporate business enterprises                        141
# 4      2012.03  Corporate business enterprises                        141
# ...        ...                             ...                        ...
# 18715  2013.03                   Pension funds                        261
# 18716  2014.03                   Pension funds                        261
# 18717  2015.03                   Pension funds                        261
# 18718  2016.03                   Pension funds                        261
# 18719  2017.03                   Pension funds                        261
#
#                                               Descriptor SNA08TRANS  \
# ...

# %%
pass

# %%
dfa['Descriptor'].nunique()
# Out:
# 105

# %%
lista = [20, 23, 24, 19, 17, 21]

sa = pd.Series(lista)

# %%
sa
# Out:
# 0    20
# 1    23
# 2    24
# 3    19
# 4    17
# 5    21
# dtype: int64

# %%
import numpy as np

# %%
sb = pd.Series(lista, index=np.arange(0, 18, 3))

# %%
sb
# Out:
# 0     20
# 3     23
# 6     24
# 9     19
# 12    17
# 15    21
# dtype: int64

# %%
dicta = {'xx':20, 'yy':30, 'zz':40}

sc = pd.Series(dicta)

# %%
sc
# Out:
# xx    20
# yy    30
# zz    40
# dtype: int64

# %%
sc['xx']
# Out:
# 20

# %%
my_list = [['John', 30000], ['Alia', 50000], ['Mia', 70000], ['Robin', 50000]]

# %%
dfe = pd.DataFrame(my_list, columns=['Name', 'Salary'])

# %%
dfe
# Out:
#     Name  Salary
# 0   John   30000
# 1   Alia   50000
# 2    Mia   70000
# 3  Robin   50000

# %%
dfe.to_excel("salaries.xlsx", index=False)

# %%
dfe['Salary'].sum()
# Out:
# 200000

# %%
import zipfile

# %%
with zipfile.ZipFile("employment-indicators-december-2020-csv.zip") as za:
    with za.open("employment-indicators-december-2020-csv-tables.csv") as f:
        dff = pd.read_csv(f)

# %%
dff
# Out:
#       Series_reference   Period    Data_value Suppressed STATUS   UNITS  \
# 0            MEIM.S1WA  1999.04  80267.000000        NaN      P  Number
# 1            MEIM.S1WA  1999.05  70803.000000        NaN      P  Number
# 2            MEIM.S1WA  1999.06  65792.000000        NaN      P  Number
# 3            MEIM.S1WA  1999.07  66194.000000        NaN      P  Number
# 4            MEIM.S1WA  1999.08  67259.000000        NaN      P  Number
# ...                ...      ...           ...        ...    ...     ...
# 13551        MEIQ.S2ZT  2019.12  34492.540698        NaN      P   Value
# 13552        MEIQ.S2ZT  2020.03  34578.110508        NaN      P   Value
# 13553        MEIQ.S2ZT  2020.06  34389.677652        NaN      P   Value
# 13554        MEIQ.S2ZT  2020.09  34494.850112        NaN      P   Value
# 13555        MEIQ.S2ZT  2020.12  34662.638299        NaN      P   Value
#
#        Magnitude                      Subject  \
# 0              0  Employment indicators - MEI
# ...

# %%
dff['Suppressed'].isNan().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-86-27eb7e700440> in <module>
# ----> 1 dff['Suppressed'].isNan().sum()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5458             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5459                 return self[name]
# -> 5460             return object.__getattribute__(self, name)
#    5461
#    5462     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'isNan'

# %%
dff.isna().sum()
# Out:
# Series_reference        0
# Period                  0
# Data_value             72
# Suppressed          13484
# STATUS                  0
# UNITS                   0
# Magnitude               0
# Subject                 0
# Group                   0
# Series_title_1          0
# Series_title_2          0
# Series_title_3          0
# Series_title_4       8696
# Series_title_5      13556
# dtype: int64

# %%
dff.shape[0]
# Out:
# 13556

# %%
dff['Data_value'].value_counts()
# Out:
# 2.070000e+03    6
# 1.958000e+03    5
# 2.176000e+03    5
# 2.221000e+03    4
# 2.681000e+03    4
#                ..
# 3.349520e+05    1
# 2.193800e+04    1
# 3.880901e+02    1
# 1.794772e+06    1
# 5.087992e+03    1
# Name: Data_value, Length: 12132, dtype: int64

# %%
dff['Suppressed'].value_counts()
# Out:
# Y    72
# Name: Suppressed, dtype: int64

# %%
#    dff.drop(index=1)

# %%
dff.head(7)
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS   UNITS  Magnitude  \
# 0        MEIM.S1WA  1999.04     80267.0        NaN      P  Number          0
# 1        MEIM.S1WA  1999.05     70803.0        NaN      P  Number          0
# 2        MEIM.S1WA  1999.06     65792.0        NaN      P  Number          0
# 3        MEIM.S1WA  1999.07     66194.0        NaN      P  Number          0
# 4        MEIM.S1WA  1999.08     67259.0        NaN      P  Number          0
# 5        MEIM.S1WA  1999.09     69691.0        NaN      P  Number          0
# 6        MEIM.S1WA  1999.10     72475.0        NaN      P  Number          0
#
#                        Subject                            Group  \
# 0  Employment indicators - MEI  High level industry by variable
# 1  Employment indicators - MEI  High level industry by variable
# 2  Employment indicators - MEI  High level industry by variable
# 3  Employment indicators - MEI  High level industry by variable
# ...

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13556 entries, 0 to 13555
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Series_reference  13556 non-null  object
#  1   Period            13556 non-null  float64
#  2   Data_value        13484 non-null  float64
#  3   Suppressed        72 non-null     object
#  4   STATUS            13556 non-null  object
#  5   UNITS             13556 non-null  object
#  6   Magnitude         13556 non-null  int64
#  7   Subject           13556 non-null  object
#  8   Group             13556 non-null  object
#  9   Series_title_1    13556 non-null  object
#  10  Series_title_2    13556 non-null  object
#  11  Series_title_3    13556 non-null  object
#  12  Series_title_4    4860 non-null   object
#  13  Series_title_5    0 non-null      float64
# dtypes: float64(3), int64(1), object(10)
# memory usage: 1.4+ MB

# %%
dff.sort_values('Data_value')
# Out:
#      Series_reference   Period  Data_value Suppressed STATUS  UNITS  \
# 3134        MEIM.S2WA  1999.06  121.018592        NaN      P  Value
# 3135        MEIM.S2WA  1999.07  122.202759        NaN      P  Value
# 3133        MEIM.S2WA  1999.05  128.424187        NaN      P  Value
# 3136        MEIM.S2WA  1999.08  128.798361        NaN      P  Value
# 3132        MEIM.S2WA  1999.04  130.783345        NaN      P  Value
# ...               ...      ...         ...        ...    ...    ...
# 6259        MEIM.S2ZT  2020.08         NaN          Y      C  Value
# 6260        MEIM.S2ZT  2020.09         NaN          Y      C  Value
# 6261        MEIM.S2ZT  2020.10         NaN          Y      C  Value
# 6262        MEIM.S2ZT  2020.11         NaN          Y      C  Value
# 6263        MEIM.S2ZT  2020.12         NaN          Y      C  Value
#
#       Magnitude                      Subject                            Group  \
# ...

# %%
dff[dff['Data_value'] < 2000].sort_index(ascending=False)
# Out:
#       Series_reference   Period   Data_value Suppressed STATUS  UNITS  \
# 12256        MEIQ.S2WT  2020.12  1428.873865        NaN      P  Value
# 12255        MEIQ.S2WT  2020.09  1416.187486        NaN      P  Value
# 12254        MEIQ.S2WT  2020.06  1394.702037        NaN      P  Value
# 12253        MEIQ.S2WT  2020.03  1379.932457        NaN      P  Value
# 12252        MEIQ.S2WT  2019.12  1375.333650        NaN      P  Value
# ...                ...      ...          ...        ...    ...    ...
# 3136         MEIM.S2WA  1999.08   128.798361        NaN      P  Value
# 3135         MEIM.S2WA  1999.07   122.202759        NaN      P  Value
# 3134         MEIM.S2WA  1999.06   121.018592        NaN      P  Value
# 3133         MEIM.S2WA  1999.05   128.424187        NaN      P  Value
# 3132         MEIM.S2WA  1999.04   130.783345        NaN      P  Value
#
#        Magnitude                      Subject  \
# 12256          6  Employment indicators - MEI
# ...

# %%
dff['Data_value']

dff.Data_value

# %%
data = {'Name':['Dima', 'James', 'Mia', 'Emity', 'Roben', 'John', 'Jordan'],
        'Verbal_Score':[151, 152, 151, 156, 100, 145, 155],
        'Quantitative_Score': [158, 87, 100, 146, 139, 129, 122],
        'Qualify': ['Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'Yes']    
}

# %%
dfg = pd.DataFrame(data)

# %%
dfg
# Out:
#      Name  Verbal_Score  Quantitative_Score Qualify
# 0    Dima           151                 158     Yes
# 1   James           152                  87      No
# 2     Mia           151                 100      No
# 3   Emity           156                 146     Yes
# 4   Roben           100                 139      No
# 5    John           145                 129     Yes
# 6  Jordan           155                 122     Yes

# %%
dfg['Verbal_Rank'] = dfg['Verbal_Score'].rank(method='min')

# %%
dfg
# Out:
#      Name  Verbal_Score  Quantitative_Score Qualify  Verbal_Rank
# 0    Dima           151                 158     Yes          3.0
# 1   James           152                  87      No          5.0
# 2     Mia           151                 100      No          3.0
# 3   Emity           156                 146     Yes          7.0
# 4   Roben           100                 139      No          1.0
# 5    John           145                 129     Yes          2.0
# 6  Jordan           155                 122     Yes          6.0

# %%
dfg['Verbal_Rank'] = dfg['Verbal_Score'].rank(method='dense')

# %%
dfg
# Out:
#      Name  Verbal_Score  Quantitative_Score Qualify  Verbal_Rank
# 0    Dima           151                 158     Yes          3.0
# 1   James           152                  87      No          4.0
# 2     Mia           151                 100      No          3.0
# 3   Emity           156                 146     Yes          6.0
# 4   Roben           100                 139      No          1.0
# 5    John           145                 129     Yes          2.0
# 6  Jordan           155                 122     Yes          5.0

# %%
dfg['Verbal_Rank'] = dfg['Verbal_Score'].rank()

# %%
dfg
# Out:
#      Name  Verbal_Score  Quantitative_Score Qualify  Verbal_Rank
# 0    Dima           151                 158     Yes          3.5
# 1   James           152                  87      No          5.0
# 2     Mia           151                 100      No          3.5
# 3   Emity           156                 146     Yes          7.0
# 4   Roben           100                 139      No          1.0
# 5    John           145                 129     Yes          2.0
# 6  Jordan           155                 122     Yes          6.0

# %%
df_cust1 = pd.read_excel('customer.xlsx', sheet_name=0)

# %%
df_cust1
# Out:
#    Cust_ID      Name
# 0      101    Olivia
# 1      102  Will LLC
# 2      103    Sophia
# 3      104  Isabella

# %%
df_cust2 = pd.read_excel('customer.xlsx', sheet_name=1)

# %%
df_cust2
# Out:
#    Order_ID  Cust_ID  Order
# 0       222      101    789
# 1       223      102    465
# 2       224      103    674
# 3       225      104    564

# %%
metadata = pd.ExcelFile('customer.xlsx')

# %%
metadata.sheet_names
# Out:
# ['wed', 'tue']

# %%
df_cust1
# Out:
#    Cust_ID      Name
# 0      101    Olivia
# 1      102  Will LLC
# 2      103    Sophia
# 3      104  Isabella

# %%
df_cust2
# Out:
#    Order_ID  Cust_ID  Order
# 0       222      101    789
# 1       223      102    465
# 2       224      103    674
# 3       225      104    564

# %%
df_cust1.join(df_cust2.set_index('Cust_ID'), how='inner', on='Cust_ID')
# Out:
#    Cust_ID      Name  Order_ID  Order
# 0      101    Olivia       222    789
# 1      102  Will LLC       223    465
# 2      103    Sophia       224    674
# 3      104  Isabella       225    564

# %%
data = {'Name':['Dima', 'James', 'Mia', 'Emity', 'Roben', 'John', 'Jordan'],
        'Salary':[50000, 45000, 51000, 60000, 41000, 21450, 34000],
        'Gender': ['F', 'M', 'F', 'F', 'M', 'M', 'M'],
        'Age': [23, 34, 36, 29, 28, 25, 30]
    
}

# %%
dfh = pd.DataFrame(data)

# %%
dfh
# Out:
#      Name  Salary Gender  Age
# 0    Dima   50000      F   23
# 1   James   45000      M   34
# 2     Mia   51000      F   36
# 3   Emity   60000      F   29
# 4   Roben   41000      M   28
# 5    John   21450      M   25
# 6  Jordan   34000      M   30

# %%
dfh_melt = dfh.melt(id_vars=['Gender'])

# %%
dfh_melt
# Out:
#    Gender variable   value
# 0       F     Name    Dima
# 1       M     Name   James
# 2       F     Name     Mia
# 3       F     Name   Emity
# 4       M     Name   Roben
# 5       M     Name    John
# 6       M     Name  Jordan
# 7       F   Salary   50000
# 8       M   Salary   45000
# 9       F   Salary   51000
# 10      F   Salary   60000
# 11      M   Salary   41000
# 12      M   Salary   21450
# 13      M   Salary   34000
# 14      F      Age      23
# 15      M      Age      34
# 16      F      Age      36
# 17      F      Age      29
# 18      M      Age      28
# 19      M      Age      25
# 20      M      Age      30

# %%
type(metadata)
# Out:
# pandas.io.excel._base.ExcelFile

# %%
dfi = pd.read_csv('bigmarket.csv')

# %%
dfi
# Out:
#     Month Store  Sales
# 0     Jan     A  31037
# 1     Jan     B  20722
# 2     Jan     C  24557
# 3     Jan     D  34649
# 4     Jan     E  29795
# 5     Feb     A  29133
# 6     Feb     B  22695
# 7     Feb     C  28312
# 8     Feb     D  31454
# 9     Feb     E  46267
# 10  March     A  32961
# 11  March     B  26451
# 12  March     C  47814
# 13  March     D  36069
# 14  March     E  31874
# 15    Apr     A  27253
# 16    Apr     B  40241
# 17    Apr     C  47488
# 18    Apr     D  25432
# 19    Apr     E  33880
# 20    May     A  29487
# 21    May     B  40001
# 22    May     C  46482
# 23    May     D  46313
# 24    May     E  47594

# %%
pd.pivot_table(dfi, index=['Month'], values=['Sales'])
# Out:
#          Sales
# Month
# Apr    34858.8
# Feb    31572.2
# Jan    28152.0
# March  35033.8
# May    41975.4

# %%
pd.pivot_table(dfi, index=['Month'], values=['Sales'], aggfunc='sum')
# Out:
#         Sales
# Month
# Apr    174294
# Feb    157861
# Jan    140760
# March  175169
# May    209877

# %%
data = {'mobile':['samsung', 'vivo', 'apple', 'redmi', 'samsung', 'vivo', 'samsung'],
        'Sales':[5000, 4500, 5100, 6000, 4100, 2145, 3400], 
        'Color':['Black', 'Blue', 'Blue', 'Black', 'Blue', 'Black', 'Blue']
}

dfm = pd.DataFrame(data)

# %%
dfm
# Out:
#     mobile  Sales  Color
# 0  samsung   5000  Black
# 1     vivo   4500   Blue
# 2    apple   5100   Blue
# 3    redmi   6000  Black
# 4  samsung   4100   Blue
# 5     vivo   2145  Black
# 6  samsung   3400   Blue

# %%
pd.crosstab(dfm['mobile'], dfm['Color'], rownames=['mobile'], colnames=['Color'])
# Out:
# Color    Black  Blue
# mobile
# apple        0     1
# redmi        1     0
# samsung      1     2
# vivo         1     1

# %%
pd.crosstab(dfm['mobile'], dfm['Color'], rownames=['mobile'], 
            colnames=['Color'], values=dfm['Sales'], aggfunc='mean')
# Out:
# Color     Black    Blue
# mobile
# apple       NaN  5100.0
# redmi    6000.0     NaN
# samsung  5000.0  3750.0
# vivo     2145.0  4500.0

# %%
type(pd.pivot)
# Out:
# function

# %%
dff
# Out:
#       Series_reference   Period    Data_value Suppressed STATUS   UNITS  \
# 0            MEIM.S1WA  1999.04  80267.000000        NaN      P  Number
# 1            MEIM.S1WA  1999.05  70803.000000        NaN      P  Number
# 2            MEIM.S1WA  1999.06  65792.000000        NaN      P  Number
# 3            MEIM.S1WA  1999.07  66194.000000        NaN      P  Number
# 4            MEIM.S1WA  1999.08  67259.000000        NaN      P  Number
# ...                ...      ...           ...        ...    ...     ...
# 13551        MEIQ.S2ZT  2019.12  34492.540698        NaN      P   Value
# 13552        MEIQ.S2ZT  2020.03  34578.110508        NaN      P   Value
# 13553        MEIQ.S2ZT  2020.06  34389.677652        NaN      P   Value
# 13554        MEIQ.S2ZT  2020.09  34494.850112        NaN      P   Value
# 13555        MEIQ.S2ZT  2020.12  34662.638299        NaN      P   Value
#
#        Magnitude                      Subject  \
# 0              0  Employment indicators - MEI
# ...

# %%
dff['Group'].value_counts()
# Out:
# High level industry by variable    7996
# Age and Region by variable         3740
# Sex and Region by variable          680
# Sex and Age by variable             440
# Industry by variable                380
# Region by variable                  320
# Name: Group, dtype: int64

# %%
dff['Subject'].value_counts()
# Out:
# Employment indicators - MEI    13556
# Name: Subject, dtype: int64

# %%
dff_group = list(dff['Group'].unique())

# %%
dff_group
# Out:
# ['High level industry by variable',
#  'Industry by variable',
#  'Region by variable',
#  'Age and Region by variable',
#  'Sex and Region by variable',
#  'Sex and Age by variable']

# %%
list_code = ['HLI', 'Ind', 'Reg', 'A&R', 'S&R', 'S&A']

# %%
z = zip(dff_group, list_code)

# %%
z

# %%
list(z)
# Out:
# [('High level industry by variable', 'HLI'),
#  ('Industry by variable', 'Ind'),
#  ('Region by variable', 'Reg'),
#  ('Age and Region by variable', 'A&R'),
#  ('Sex and Region by variable', 'S&R'),
#  ('Sex and Age by variable', 'S&A')]

# %%
list(z)
# Out:
# []

# %%
z = zip(list_code, dff_group)

# %%
codes = dict(z)

# %%
codes
# Out:
# {'HLI': 'High level industry by variable',
#  'Ind': 'Industry by variable',
#  'Reg': 'Region by variable',
#  'A&R': 'Age and Region by variable',
#  'S&R': 'Sex and Region by variable',
#  'S&A': 'Sex and Age by variable'}

# %%
dff
# Out:
#       Series_reference   Period    Data_value Suppressed STATUS   UNITS  \
# 0            MEIM.S1WA  1999.04  80267.000000        NaN      P  Number
# 1            MEIM.S1WA  1999.05  70803.000000        NaN      P  Number
# 2            MEIM.S1WA  1999.06  65792.000000        NaN      P  Number
# 3            MEIM.S1WA  1999.07  66194.000000        NaN      P  Number
# 4            MEIM.S1WA  1999.08  67259.000000        NaN      P  Number
# ...                ...      ...           ...        ...    ...     ...
# 13551        MEIQ.S2ZT  2019.12  34492.540698        NaN      P   Value
# 13552        MEIQ.S2ZT  2020.03  34578.110508        NaN      P   Value
# 13553        MEIQ.S2ZT  2020.06  34389.677652        NaN      P   Value
# 13554        MEIQ.S2ZT  2020.09  34494.850112        NaN      P   Value
# 13555        MEIQ.S2ZT  2020.12  34662.638299        NaN      P   Value
#
#        Magnitude                      Subject  \
# 0              0  Employment indicators - MEI
# ...

# %%
dff_copy = dff.copy()

# %%
dff_copy['Group'] = dff_copy['Group'].replace(dff_group, list_code)

# %%
dff_copy
# Out:
#       Series_reference   Period    Data_value Suppressed STATUS   UNITS  \
# 0            MEIM.S1WA  1999.04  80267.000000        NaN      P  Number
# 1            MEIM.S1WA  1999.05  70803.000000        NaN      P  Number
# 2            MEIM.S1WA  1999.06  65792.000000        NaN      P  Number
# 3            MEIM.S1WA  1999.07  66194.000000        NaN      P  Number
# 4            MEIM.S1WA  1999.08  67259.000000        NaN      P  Number
# ...                ...      ...           ...        ...    ...     ...
# 13551        MEIQ.S2ZT  2019.12  34492.540698        NaN      P   Value
# 13552        MEIQ.S2ZT  2020.03  34578.110508        NaN      P   Value
# 13553        MEIQ.S2ZT  2020.06  34389.677652        NaN      P   Value
# 13554        MEIQ.S2ZT  2020.09  34494.850112        NaN      P   Value
# 13555        MEIQ.S2ZT  2020.12  34662.638299        NaN      P   Value
#
#        Magnitude                      Subject Group  Series_title_1  \
# ...

# %%
dff['Suppressed'] = dff['Suppressed'].fillna(0)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 13551    0
# 13552    0
# 13553    0
# 13554    0
# 13555    0
# Name: Suppressed, Length: 13556, dtype: object

# %%
dff
# Out:
#       Series_reference   Period    Data_value Suppressed STATUS   UNITS  \
# 0            MEIM.S1WA  1999.04  80267.000000        NaN      P  Number
# 1            MEIM.S1WA  1999.05  70803.000000        NaN      P  Number
# 2            MEIM.S1WA  1999.06  65792.000000        NaN      P  Number
# 3            MEIM.S1WA  1999.07  66194.000000        NaN      P  Number
# 4            MEIM.S1WA  1999.08  67259.000000        NaN      P  Number
# ...                ...      ...           ...        ...    ...     ...
# 13551        MEIQ.S2ZT  2019.12  34492.540698        NaN      P   Value
# 13552        MEIQ.S2ZT  2020.03  34578.110508        NaN      P   Value
# 13553        MEIQ.S2ZT  2020.06  34389.677652        NaN      P   Value
# 13554        MEIQ.S2ZT  2020.09  34494.850112        NaN      P   Value
# 13555        MEIQ.S2ZT  2020.12  34662.638299        NaN      P   Value
#
#        Magnitude                      Subject  \
# 0              0  Employment indicators - MEI
# ...

# %%
dff['Suppressed'] = dff['Suppressed'].fillna(0)

# %%
dff
# Out:
#       Series_reference   Period    Data_value Suppressed STATUS   UNITS  \
# 0            MEIM.S1WA  1999.04  80267.000000          0      P  Number
# 1            MEIM.S1WA  1999.05  70803.000000          0      P  Number
# 2            MEIM.S1WA  1999.06  65792.000000          0      P  Number
# 3            MEIM.S1WA  1999.07  66194.000000          0      P  Number
# 4            MEIM.S1WA  1999.08  67259.000000          0      P  Number
# ...                ...      ...           ...        ...    ...     ...
# 13551        MEIQ.S2ZT  2019.12  34492.540698          0      P   Value
# 13552        MEIQ.S2ZT  2020.03  34578.110508          0      P   Value
# 13553        MEIQ.S2ZT  2020.06  34389.677652          0      P   Value
# 13554        MEIQ.S2ZT  2020.09  34494.850112          0      P   Value
# 13555        MEIQ.S2ZT  2020.12  34662.638299          0      P   Value
#
#        Magnitude                      Subject  \
# 0              0  Employment indicators - MEI
# ...

# %%
dfm
# Out:
#     mobile  Sales  Color
# 0  samsung   5000  Black
# 1     vivo   4500   Blue
# 2    apple   5100   Blue
# 3    redmi   6000  Black
# 4  samsung   4100   Blue
# 5     vivo   2145  Black
# 6  samsung   3400   Blue

# %%
dfm_1 = dfm.copy()

dfm_2 = dfm

# %%
dfm
# Out:
#     mobile  Sales  Color
# 0  samsung   5000  Black
# 1     vivo   4500   Blue
# 2    apple   5100   Blue
# 3    redmi   6000  Black
# 4  samsung   4100   Blue
# 5     vivo   2145  Black
# 6  samsung   3400   Blue

# %%
dfm.replace(to_replace='Black', value='Red', inplace=True)

# %%
dfm
# Out:
#     mobile  Sales Color
# 0  samsung   5000   Red
# 1     vivo   4500  Blue
# 2    apple   5100  Blue
# 3    redmi   6000   Red
# 4  samsung   4100  Blue
# 5     vivo   2145   Red
# 6  samsung   3400  Blue

# %%
dfm_2
# Out:
#     mobile  Sales Color
# 0  samsung   5000   Red
# 1     vivo   4500  Blue
# 2    apple   5100  Blue
# 3    redmi   6000   Red
# 4  samsung   4100  Blue
# 5     vivo   2145   Red
# 6  samsung   3400  Blue

# %%
dfm_1
# Out:
#     mobile  Sales  Color
# 0  samsung   5000  Black
# 1     vivo   4500   Blue
# 2    apple   5100   Blue
# 3    redmi   6000  Black
# 4  samsung   4100   Blue
# 5     vivo   2145  Black
# 6  samsung   3400   Blue

# %%
help(dfa.plot)
# Out:
# Help on PlotAccessor in module pandas.plotting._core object:
#
# class PlotAccessor(pandas.core.base.PandasObject)
#  |  PlotAccessor(data)
#  |
#  |  Make plots of Series or DataFrame.
#  |
#  |  Uses the backend specified by the
#  |  option ``plotting.backend``. By default, matplotlib is used.
#  |
#  |  Parameters
#  |  ----------
#  |  data : Series or DataFrame
#  |      The object for which the method is called.
#  |  x : label or position, default None
#  |      Only used if data is a DataFrame.
#  |  y : label, position or list of label, positions, default None
#  |      Allows plotting of one column versus another. Only used if data is a
#  |      DataFrame.
#  |  kind : str
#  |      The kind of plot to produce:
#  |
#  |      - 'line' : line plot (default)
#  |      - 'bar' : vertical bar plot
#  |      - 'barh' : horizontal bar plot
#  |      - 'hist' : histogram
#  |      - 'box' : boxplot
#  |      - 'kde' : Kernel Density Estimation plot
# ...

# %%
dfg
# Out:
#      Name  Verbal_Score  Quantitative_Score Qualify  Verbal_Rank
# 0    Dima           151                 158     Yes          3.5
# 1   James           152                  87      No          5.0
# 2     Mia           151                 100      No          3.5
# 3   Emity           156                 146     Yes          7.0
# 4   Roben           100                 139      No          1.0
# 5    John           145                 129     Yes          2.0
# 6  Jordan           155                 122     Yes          6.0

# %%
import matplotlib.pyplot as plt

plt.plot(dfg.index, dfg['Verbal_Score'])
plt.show()

# %%
dfg['Verbal_Score'].plot(kind='bar')
plt.show()
